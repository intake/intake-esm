# %%
# %load_ext autoreload
# %autoreload 2

# %%
import intake

# %%
cdefiniton = './tests/mpi-ge.yml'

# %%
col = intake.open_esm_metadatastore(collection_input_definition=cdefiniton, 
                                    overwrite_existing=True)
# Out:
# Working on experiment: pictrl
# Getting file listing : SAMPLE-DATA:input-file:./tests/mpi_filelist.txt
# Building file database : SAMPLE-DATA:input-file:./tests/mpi_filelist.txt
# Could not extract date string from : rcp850001_mpiom_map.nc
# Could not identify MPI-GE fileparts for : rcp850001_mpiom_map.nc
# Could not extract date string from : rcp850001_mpiom_fx.nc
# Could not identify MPI-GE fileparts for : rcp850001_mpiom_fx.nc
# Working on experiment: hist
# Getting file listing : SAMPLE-DATA:input-file:./tests/mpi_filelist.txt
# Building file database : SAMPLE-DATA:input-file:./tests/mpi_filelist.txt
# Could not extract date string from : rcp850001_mpiom_map.nc
# Could not identify MPI-GE fileparts for : rcp850001_mpiom_map.nc
# Could not extract date string from : rcp850001_mpiom_fx.nc
# Could not identify MPI-GE fileparts for : rcp850001_mpiom_fx.nc
# Working on experiment: rcp85
# Getting file listing : SAMPLE-DATA:input-file:./tests/mpi_filelist.txt
# ...

# %%
col.df.head(10)
# Out:
#                                           resource resource_type  \
# 0  SAMPLE-DATA:input-file:./tests/mpi_filelist.txt    input-file
# 1  SAMPLE-DATA:input-file:./tests/mpi_filelist.txt    input-file
# 2  SAMPLE-DATA:input-file:./tests/mpi_filelist.txt    input-file
# 3  SAMPLE-DATA:input-file:./tests/mpi_filelist.txt    input-file
# 4  SAMPLE-DATA:input-file:./tests/mpi_filelist.txt    input-file
# 5  SAMPLE-DATA:input-file:./tests/mpi_filelist.txt    input-file
# 6  SAMPLE-DATA:input-file:./tests/mpi_filelist.txt    input-file
# 7  SAMPLE-DATA:input-file:./tests/mpi_filelist.txt    input-file
# 8  SAMPLE-DATA:input-file:./tests/mpi_filelist.txt    input-file
# 9  SAMPLE-DATA:input-file:./tests/mpi_filelist.txt    input-file
#
#    direct_access       case component         stream         date_range  \
# 0          False  rcp850001     mpiom     data_2d_mm  20740101-20741231
# 1          False  rcp850001     mpiom     data_2d_mm  20720101-20721231
# ...

# %%
col.df.columns
# Out:
# Index(['resource', 'resource_type', 'direct_access', 'case', 'component',
#        'stream', 'date_range', 'file_basename', 'file_dirname',
#        'file_fullpath'],
#       dtype='object')
