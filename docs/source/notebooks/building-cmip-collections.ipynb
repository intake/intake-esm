# %% [markdown]
# # Building CMIP5 Collection Catalog

# %% [markdown]
# This notebook demonstrates how to generate CMIP5 collection catalog using `intake_cesm` for CMIP5 datasets residing on NCAR's GLADE file system.

# %%
# Import Packages
from dask.distributed import Client
import dask
from dask_jobqueue import SLURMCluster
import os
PROJECT = os.environ["PBS_ACCOUNT"]

# %%
# Create Dask Cluster using Jobqueue to speed up collection catalog generation
cluster = SLURMCluster(project=PROJECT, processes=6, cores=12, memory="10GB",
                           env_extra=['export LANG="en_US.utf8"',
                                      'export LANGUAGE="en_US.utf8"',
                                      'export LC_ALL="en_US.utf8"',
                                      'export LD_LIBRARY_PATH=""',])

# %%
cluster.adapt(minimum=12, maximum=24)

# %%
# !squeue -u $USER
# Out:
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
#            2235786       dav dask-wor  abanihi  R       0:06      1 casper03
#            2235787       dav dask-wor  abanihi  R       0:06      1 casper02
#            2235596       dav     srun  abanihi  R      27:49      1 casper05

# %%
client = Client(cluster)

# %%
client
# Out:
# <Client: scheduler='tcp://10.12.205.14:36282' processes=12 cores=24>

# %%
import intake

# %% [markdown]
# To build a CMIP collection catalog, the user needs to have a YAML input file with the following content:
#
# E.g: `cmip_collection_input.yml`
#
# ```yaml
# name: cmip5
# collection_type: cmip
# overwriting_existing: true
# include_cache_dir : true
# data_sources:
#   root_dir:
#     name: GLADE
#     loc_type: posix
#     direct_access: True
#     urlpath: /glade/collections/cmip/cmip5
# ```

# %%
# %time col = intake.open_esm_metadatastore(collection_input_file="cmip_collection_input.yml", collection_type="cmip")
# Out:
# None
# Persisting cmip5 at : /glade/u/home/abanihi/.intake_esm/database_directory/cmip/cmip5.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87631 entries, 0 to 87630
# Data columns (total 11 columns):
# ensemble         87631 non-null object
# experiment       87631 non-null object
# file_basename    87631 non-null object
# file_fullpath    87631 non-null object
# frequency        87631 non-null object
# institution      87631 non-null object
# model            87631 non-null object
# realm            87631 non-null object
# files_dirname    87631 non-null object
# variable         87631 non-null object
# version          87631 non-null object
# dtypes: object(11)
# memory usage: 7.4+ MB
# CPU times: user 23.2 s, sys: 2.45 s, total: 25.6 s
# Wall time: 1min 34s

# %%
col.df.head()
# Out:
#   ensemble experiment                                   file_basename  \
# 0   r1i1p1      rcp85  ua_Amon_GFDL-CM3_rcp85_r1i1p1_209601-210012.nc
# 1   r4i1p1      rcp85   ua_Amon_CanESM2_rcp85_r4i1p1_200601-210012.nc
# 2   r2i1p1      rcp85   ua_Amon_CanESM2_rcp85_r2i1p1_200601-210012.nc
# 3   r5i1p1      rcp85   ua_Amon_CanESM2_rcp85_r5i1p1_200601-210012.nc
# 4   r3i1p1      rcp85   ua_Amon_CanESM2_rcp85_r3i1p1_200601-210012.nc
#
#                                        file_fullpath frequency institution  \
# 0  /glade/collections/cmip/cmip5/output1/NOAA-GFD...       mon   NOAA-GFDL
# 1  /glade/collections/cmip/cmip5/output1/CCCma/Ca...       mon       CCCma
# 2  /glade/collections/cmip/cmip5/output1/CCCma/Ca...       mon       CCCma
# 3  /glade/collections/cmip/cmip5/output1/CCCma/Ca...       mon       CCCma
# 4  /glade/collections/cmip/cmip5/output1/CCCma/Ca...       mon       CCCma
#
#       model  realm                                      files_dirname  \
# 0  GFDL-CM3  atmos  /glade/collections/cmip/cmip5/output1/NOAA-GFD...
# 1   CanESM2  atmos  /glade/collections/cmip/cmip5/output1/CCCma/Ca...
# 2   CanESM2  atmos  /glade/collections/cmip/cmip5/output1/CCCma/Ca...
# 3   CanESM2  atmos  /glade/collections/cmip/cmip5/output1/CCCma/Ca...
# 4   CanESM2  atmos  /glade/collections/cmip/cmip5/output1/CCCma/Ca...
#
#   variable version
# 0       ua      v0
# 1       ua      v0
# 2       ua      v0
# 3       ua      v0
# 4       ua      v0

# %%
col.df.model.nunique()  # Find the total number of unique climate models
# Out:
# 55

# %%
col.df.realm.unique()  # find the list of unique realms
# Out:
# array(['atmos', 'aerosol', 'seaIce', 'landIce', 'land', 'ocean',
#        'ocnBgchem'], dtype=object)

# %%
col.df.variable.nunique() # How many unique variables
# Out:
# 454

# %%
col.df.tail()
# Out:
#       ensemble  experiment                                      file_basename  \
# 87626   r1i1p1       rcp85  ua_day_ACCESS1-0_rcp85_r1i1p1_20960101-2100123...
# 87627   r1i1p1       rcp85  tasmin_day_ACCESS1-0_rcp85_r1i1p1_20810101-210...
# 87628   r1i1p1  historical  va_day_ACCESS1-0_historical_r1i1p1_20050101-20...
# 87629   r1i1p1       rcp85  tasmax_day_ACCESS1-0_rcp85_r1i1p1_20810101-210...
# 87630   r1i1p1  historical  ua_day_ACCESS1-0_historical_r1i1p1_20050101-20...
#
#                                            file_fullpath frequency  \
# 87626  /glade/collections/cmip/cmip5/output1/CSIRO-BO...       day
# 87627  /glade/collections/cmip/cmip5/output1/CSIRO-BO...       day
# 87628  /glade/collections/cmip/cmip5/output1/CSIRO-BO...       day
# 87629  /glade/collections/cmip/cmip5/output1/CSIRO-BO...       day
# 87630  /glade/collections/cmip/cmip5/output1/CSIRO-BO...       day
#
#       institution      model  realm  \
# 87626   CSIRO-BOM  ACCESS1-0  atmos
# 87627   CSIRO-BOM  ACCESS1-0  atmos
# 87628   CSIRO-BOM  ACCESS1-0  atmos
# 87629   CSIRO-BOM  ACCESS1-0  atmos
# 87630   CSIRO-BOM  ACCESS1-0  atmos
#
#                                            files_dirname variable version
# 87626  /glade/collections/cmip/cmip5/output1/CSIRO-BO...       ua      v4
# 87627  /glade/collections/cmip/cmip5/output1/CSIRO-BO...   tasmin      v4
# 87628  /glade/collections/cmip/cmip5/output1/CSIRO-BO...       va      v4
# 87629  /glade/collections/cmip/cmip5/output1/CSIRO-BO...   tasmax      v4
# 87630  /glade/collections/cmip/cmip5/output1/CSIRO-BO...       ua      v4

# %%
# %time len(col.df) # Find the total number of files available in generated CMIP5 database
# Out:
# CPU times: user 15 µs, sys: 0 ns, total: 15 µs
# Wall time: 18.1 µs
# 87631

# %%
col.df.groupby('model').nunique()
# Out:
#                 ensemble  experiment  file_basename  file_fullpath  frequency  \
# model
# ACCESS1-0              3           3            190            190          4
# ACCESS1-3              3           6            213            213          4
# ACCESS1.0              2           3              3              3          1
# BNU-ESM                1           6             79             79          4
# CCSM4                 87          44          55336          55336          5
# CESM1-BGC             15          12           3804           3804          4
# CESM1-CAM5            37          16           7075           7075          5
# CESM1-FASTCHEM         5           2            633            633          3
# CESM1-WACCM           12           5           3214           3214          3
# CMCC-CESM              1           2             73             73          2
# CMCC-CM                1           4             47             47          4
# CMCC-CMS               1           4             42             42          2
# CNRM-CM5              10           4            305            305          4
# CNRM-CM5-2             1           1             15             15          1
# CSIRO-Mk3-6-0         42           8           1232           1232          3
# CSIRO-Mk3L-1-2         3           2             48             48          1
# CanCM4                10           2            150            150          1
# CanESM2               17          11            839            839          3
# EC-EARTH              13           3            344            344          3
# FGOALS-g2              5           6            139            139          4
# FGOALS-s2              3           2             38             38          1
# FIO-ESM                3           4             88             88          1
# GFDL-CM2p1            10           1             40             40          1
# GFDL-CM3               5           4            458            458          4
# GFDL-ESM2G             3           8            548            548          5
# GFDL-ESM2M             8           9            624            624          5
# GISS-E2-H            113           8           1762           1762          4
# GISS-E2-H-CC           1           3             73             73          1
# GISS-E2-R            137           8           1936           1936          4
# GISS-E2-R-CC           1           3             73             73          1
# HadCM3                10           2            404            404          2
# HadGEM2-A              1           1              5              5          1
# HadGEM2-AO             1           3             53             53          2
# HadGEM2-CC             3           3            456            456          3
# HadGEM2-ES             5           6           1144           1144          5
# IPSL-CM5A-LR          20           8           1421           1421          5
# IPSL-CM5A-MR           6           4            344            344          4
# IPSL-CM5B-LR           1           3            145            145          3
# MIROC-ESM              3           8            351            351          5
# MIROC-ESM-CHEM         9           5            203            203          4
# MIROC4h                3           2            205            205          2
# MIROC5                 5           5            848            848          4
# MPI-ESM-LR             3           9            905            905          4
# MPI-ESM-MR             3           4            256            256          3
# MPI-ESM-P              2           1             32             32          2
# MRI-AGCM3-2H           1           1              5              5          1
# MRI-AGCM3-2S           1           1              3              3          1
# MRI-CGCM3              5           4            411            411          4
# MRI-ESM1               1           5            237            237          4
# NorESM1-M              3           4            264            264          4
# NorESM1-ME             2           8            262            262          2
# bcc-csm1-1             3           9             71             71          3
# bcc-csm1-1-m           3           9             74             74          3
# fio-esm                3           7             32             32          1
# inmcm4                 1           6             79             79          5
#
#                 institution  model  realm  files_dirname  variable  version
# model
# ACCESS1-0                 1      1      4            190        59       11
# ACCESS1-3                 1      1      3            213        53       17
# ACCESS1.0                 1      1      1              3         1        1
# BNU-ESM                   1      1      6             79        43        3
# CCSM4                     1      1      5          55336       190       95
# CESM1-BGC                 1      1      6           3804       219       22
# CESM1-CAM5                1      1      6           7075       181       52
# CESM1-FASTCHEM            1      1      5            633       152        6
# CESM1-WACCM               1      1      5           3214       156       19
# CMCC-CESM                 1      1      5             73        46        6
# CMCC-CM                   1      1      4             47        19        6
# CMCC-CMS                  1      1      4             42        16        2
# CNRM-CM5                  1      1      5            305        57       12
# CNRM-CM5-2                1      1      2             15        15        1
# CSIRO-Mk3-6-0             1      1      4           1232        58        4
# CSIRO-Mk3L-1-2            1      1      2             48         9        2
# CanCM4                    1      1      2            150        10        1
# CanESM2                   1      1      7            839       113       10
# EC-EARTH                  1      1      2            344        18       34
# FGOALS-g2                 1      1      4            139        33        5
# FGOALS-s2                 1      1      2             38        12        2
# FIO-ESM                   1      1      4             88        36        4
# GFDL-CM2p1                1      1      2             40         4        1
# GFDL-CM3                  1      1      3            458        90        3
# GFDL-ESM2G                1      1      5            548       191        6
# GFDL-ESM2M                1      1      5            624       255        6
# GISS-E2-H                 1      1      4           1762        74       20
# GISS-E2-H-CC              1      1      4             73        55        3
# GISS-E2-R                 1      1      4           1936        75       32
# GISS-E2-R-CC              1      1      4             73        55        4
# HadCM3                    1      1      3            404        23        4
# HadGEM2-A                 1      1      1              5         5        1
# HadGEM2-AO                1      1      2             53        15        2
# HadGEM2-CC                1      1      3            456        71       19
# HadGEM2-ES                2      1      5           1144       194       30
# IPSL-CM5A-LR              1      1      5           1421       153       14
# IPSL-CM5A-MR              1      1      4            344        92        5
# IPSL-CM5B-LR              1      1      4            145        90        3
# MIROC-ESM                 1      1      7            351       108        8
# MIROC-ESM-CHEM            1      1      6            203        72        7
# MIROC4h                   1      1      4            205        56        4
# MIROC5                    1      1      5            848        72       15
# MPI-ESM-LR                1      1      6            905       161        7
# MPI-ESM-MR                1      1      5            256        78        2
# MPI-ESM-P                 1      1      3             32        14        1
# MRI-AGCM3-2H              1      1      1              5         5        1
# MRI-AGCM3-2S              1      1      1              3         3        1
# MRI-CGCM3                 1      1      5            411        72        8
# MRI-ESM1                  1      1      7            237       134        5
# NorESM1-M                 1      1      4            264        65        5
# NorESM1-ME                1      1      6            262       126        4
# bcc-csm1-1                1      1      6             71        36        4
# bcc-csm1-1-m              1      1      6             74        36        6
# fio-esm                   1      1      3             32        10        4
# inmcm4                    1      1      5             79        45        2

# %%
# %load_ext watermark

# %%
# %watermark --iversion -g -h -m -v -u -d
# Out:
# dask   1.1.1
# intake 0.4.1
# last updated: 2019-03-01
#
# CPython 3.6.7
# IPython 7.1.1
#
# compiler   : GCC 7.3.0
# system     : Linux
# release    : 3.10.0-693.21.1.el7.x86_64
# machine    : x86_64
# processor  : x86_64
# CPU cores  : 72
# interpreter: 64bit
# host name  : casper05
# Git hash   : 7bc09705408cff3a1dadf2f5cd15ccb79b53c958
